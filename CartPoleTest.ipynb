# %% [markdown]
# # Neccessary Setup
#
# This part of the code can be changed as per the environment we are working on, this traing was done completely on google collab except the finetuning and final testing.

# %%
# !pip uninstall -y numpy gym scipy pyglet scikit-optimize

# Install latest stable versions
# !pip install numpy==1.26.4
# !pip install scipy==1.13.1
#!pip install gym==0.26.2
#!pip install gym-notices==0.0.8
#!pip install --upgrade gym
# !pip install --upgrade gymnasium
# !pip install scikit-optimize==0.9.0
# !pip install pyglet==1.5.27
# !pip install pyvirtualdisplay
# !apt-get install -y xvfb ffmpeg > /dev/null 2>&1
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: gym 0.25.2
# Uninstalling gym-0.25.2:
#   Successfully uninstalled gym-0.25.2
# Found existing installation: scipy 1.16.3
# Uninstalling scipy-1.16.3:
#   Successfully uninstalled scipy-1.16.3
# WARNING: Skipping pyglet as it is not installed.
# WARNING: Skipping scikit-optimize as it is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 68.6 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.7.0 requires scipy>=1.12.0, which is not installed.
# osqp 1.1.1 requires scipy>=0.13.2, which is not installed.
# jax 0.7.2 requires scipy>=1.13, which is not installed.
# ...

# %%
import numpy as np

# Patch for older Gym code that expects np.bool8
if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

np.int = int
# Out:
# /tmp/ipykernel_44471/224723022.py:4: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not hasattr(np, "bool8"):

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: Go to the path Cart_Pole_problem

# %cd /content/drive/MyDrive/Cart_Pole_problem_test
# Out:
# /content/drive/MyDrive/Cart_Pole_problem_test

# %%
# !git clone https://github.com/ShinigamiXX/constrained-cartpole-rl.git
# %cd constrained-cartpole-rl
# Out:
# fatal: destination path 'constrained-cartpole-rl' already exists and is not an empty directory.
# /content/constrained-cartpole-rl

# %%
# !git config --global user.name "SaxenaNamanBase"
# !git config --global user.email "namanrossouw@gmail.com"

# %%
import getpass, os

# Ask securely for your token
os.environ['GITHUB_TOKEN'] = getpass.getpass('Enter your GitHub token: ')

# Set up authentication
# !git remote set-url origin https://SaxenaNamanBase:${GITHUB_TOKEN}@github.com/SaxenaNamanBase/constrained-cartpole-rl.git
# Out:
# Enter your GitHub token: ··········

# %%
# !git add .
# !git commit -m "Updated multiple files after testing"
# !git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# remote: Permission to SaxenaNamanBase/constrained-cartpole-rl.git denied to SaxenaNamanBase.
# fatal: unable to access 'https://github.com/SaxenaNamanBase/constrained-cartpole-rl.git/': The requested URL returned error: 403

# %%
from google.colab import userdata
import os

# 1. Retrieve secrets securely
gh_token = userdata.get('GH_TOKEN')
gh_user = userdata.get('GH_USERNAME')
gh_email = userdata.get('GH_EMAIL')
repo_name = "constrained-cartpole-rl"

# 2. Configure Git using the retrieved secrets
# !git config --global user.name "{gh_user}"
# !git config --global user.email "{gh_email}"

# 3. Construct the remote URL and push
# Using the {variable} syntax to pass Python strings to the shell
remote_url = f"https://{gh_user}:{gh_token}@github.com/{gh_user}/{repo_name}.git"

# !git remote set-url origin {remote_url}
# !git add .
# !git commit -m "Made everything generalised and tested for qlearning first"
# !git push origin main
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 140, done.
# Counting objects: 100% (140/140), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (133/133), done.
# Writing objects: 100% (133/133), 2.64 MiB | 5.49 MiB/s, done.
# Total 133 (delta 11), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (11/11), completed with 6 local objects.
# To https://github.com/SaxenaNamanBase/constrained-cartpole-rl.git
#    65eb629..ea72fe2  main -> main

# %%
# !git rebase --abort
# Out:
# fatal: No rebase in progress?

# %%
# %%writefile .gitignore
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# Out:
# Overwriting .gitignore

# %%
# !git add .

# %%
# !git commit -m "Working on the changing mode"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push --force
# Out:
# Enumerating objects: 298, done.
# Counting objects: 100% (298/298), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (122/122), done.
# Writing objects: 100% (298/298), 4.28 MiB | 13.77 MiB/s, done.
# Total 298 (delta 187), reused 257 (delta 174), pack-reused 0
# remote: Resolving deltas: 100% (187/187), done.
# To https://github.com/SaxenaNamanBase/constrained-cartpole-rl.git
#  + 84cb064...6c4d810 main -> main (forced update)

# %% [markdown]
# # Prerequisites
#
# Includes the files that need to be imported to run this main file

# %%
import gymnasium as gym
from gym_wrapper import GymWrapper
from hardware_interface import HardwareInterface
from control_algorithm import QLearningControl, SarsaControl, DQNControl
from data_logger import DataLogger
import config
import matplotlib.pyplot as plt
import numpy as np
from exploration_strategies import EpsilonGreedyStrategy, SoftmaxStrategy

from hyperparameter_tuning import tune_hyperparameters_qlearning, tune_hyperparameters_sarsa
from hyperparameter_tuning import tune_hyperparameters_dqn
from cross_validation import train_dqn
from cross_validation import run_cross_validation_or_training

# %% [markdown]
# # Selecting Model
#
# In this section we can choose which model we need to work with

# %%
##   We can comment or activate the model lines we need


#model='dqn'
model='qlearning'
#model='sarsa'

# %% [markdown]
# # Hyperparameter Tuning
#
# This section is to be used for the initial hyperparameter tuning for the bets initial hyperparameters.

# %%
model_map = {
    'dqn': {
        'control_class': DQNControl,
        'tuning_function': tune_hyperparameters_dqn
    },
    'qlearning': {
        'control_class': QLearningControl,
        'tuning_function': tune_hyperparameters_qlearning
    },
    'sarsa': {
        'control_class': SarsaControl,
        'tuning_function': tune_hyperparameters_sarsa
    }
}

# Get the control class and tuning function for the selected model
control_class = model_map[model]['control_class']
tuning_function = model_map[model]['tuning_function']

# Perform hyperparameter tuning
tuning_function(control_class, EpsilonGreedyStrategy, config)

# Initialize environment
use_hardware = False  # Set to True when using physical hardware

if use_hardware:
    env = HardwareInterface(config.HARDWARE_PARAMS)
else:
    # Use gymnasium.make instead of gym.make
    env = GymWrapper(gym.make('CartPole-v1'))

state_dim = env.observation_space[0]         ##############
action_dim = env.env.action_space.n          ##############

# Initialize exploration strategy
exploration_strategy = EpsilonGreedyStrategy(epsilon=config.CONTROL_PARAMS['epsilon'])

# Initialize the controller using the selected model's control class
#controller = control_class(config.CONTROL_PARAMS, exploration_strategy)

'''controller = control_class(
    config.CONTROL_PARAMS,
    exploration_strategy,
    state_dim,    # <--- PASSED
    action_dim    # <--- PASSED
)'''
if model == 'dqn':
    # DQN needs the dimensions for the neural network architecture
    controller = control_class(
        config.CONTROL_PARAMS,
        exploration_strategy,
        state_dim,
        action_dim
    )
else:
    # QLearning and SARSA are tabular and only require the two main arguments
    controller = control_class(
        config.CONTROL_PARAMS,
        exploration_strategy
    )
# Out:
# Best Parameters Updated in CONTROL_PARAMS:
# Learning Rate: 0.1
# Discount Factor: 0.8930197440432727
# Epsilon: 0.1630519821040166
# Best Score: 58.314

# %% [markdown]
# # Training the model
# This section is to be used for training and saving the model and displaying outputs for Sarsa and QLearning only

# %%
'''import ipywidgets as widgets
from IPython.display import display, clear_output

# Define the dropdowns
algo_select = widgets.Dropdown(
    options=[('Q-Learning', 'qlearning'), ('DQN', 'dqn'), ('SARSA', 'sarsa')],
    value='qlearning',
    description='Algorithm:',
)

mode_select = widgets.Dropdown(
    options=[('2D (Pole Only)', '2D'), ('4D (Full State)', '4D')],
    value='2D',
    description='State Mode:',
)

logic_select = widgets.Dropdown(
    options=[('Fixed Episodes', 'fixed'), ('Until Overfitting', 'overfitting')],
    value='fixed',
    description='Stop Logic:',
)

action_select = widgets.Dropdown(
    options=[('Discrete (0 or 1)', 'discrete'), ('Continuous (-1 to 1)', 'continuous')],
    value='discrete',
    description='Action Type:',
)

run_button = widgets.Button(
    description='Launch Training',
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    icon='play'
)

out = widgets.Output()

# Define what happens when you click the button
def on_button_clicked(b):
    with out:
        clear_output()
        print(f"🚀 Initializing {algo_select.label} in {mode_select.value} mode...")

        # This calls your updated cross_validation.py function
        controller = run_cross_validation_or_training(
            algorithm=algo_select.value,
            mode=mode_select.value,
            action_mode=action_select.value,
            stop_logic=logic_select.value
        )

        print(f"✅ Training Complete! Model is stored in 'controller' variable.")
        # You can also save the controller to a global variable to use it in other cells
        globals()['latest_controller'] = controller

run_button.on_click(on_button_clicked)

# Display everything
display(algo_select, mode_select, action_select, logic_select, run_button, out)'''

import ipywidgets as widgets
from IPython.display import display, clear_output
import numpy as np

# 1. Define all widgets first
algo_select = widgets.Dropdown(
    options=[('Q-Learning', 'qlearning'), ('DQN', 'dqn'), ('SARSA', 'sarsa')],
    value='qlearning',
    description='Algorithm:',
)

mode_select = widgets.Dropdown(
    options=[('2D (Pole Only)', '2D'), ('4D (Full State)', '4D')],
    value='2D',
    description='State Mode:',
)

action_select = widgets.Dropdown(
    options=[('Discrete (0 or 1)', 'discrete')],
    value='discrete',
    description='Action Type:',
)

logic_select = widgets.Dropdown(
    options=[('Fixed Episodes', 'fixed'), ('Until Overfitting', 'overfitting')],
    value='fixed',
    description='Stop Logic:',
)

tune_toggle = widgets.Checkbox(
    value=False,
    description='Tune Hyperparameters?',
    indent=False
)

run_button = widgets.Button(
    description='Launch Training',
    button_style='success',
    icon='play'
)

out = widgets.Output()

# 2. Add the dynamic observer for Action Type
def update_action_options(*args):
    if algo_select.value == 'dqn':
        action_select.options = [('Discrete (0 or 1)', 'discrete'), ('Continuous (-1 to 1)', 'continuous')]
    else:
        action_select.options = [('Discrete (0 or 1)', 'discrete')]
        action_select.value = 'discrete'

algo_select.observe(update_action_options, 'value')

# 3. Define the click logic
def on_button_clicked(b):
    with out:
        clear_output()
        algo = algo_select.value

        # Define the map inside the function so it's always fresh
        model_map = {
            'dqn': {'control_class': DQNControl, 'tuning_function': tune_hyperparameters_dqn},
            'qlearning': {'control_class': QLearningControl, 'tuning_function': tune_hyperparameters_qlearning},
            'sarsa': {'control_class': SarsaControl, 'tuning_function': tune_hyperparameters_sarsa}
        }

        selected_model = model_map[algo]

        # --- PHASE 1: TUNING ---
        if tune_toggle.value:
            print(f"🔎 Starting Hyperparameter Tuning for {algo}...")
            selected_model['tuning_function'](selected_model['control_class'], EpsilonGreedyStrategy, config)
            print("✅ Tuning complete. Updated config with best parameters.")

        # --- PHASE 2: TRAINING ---
        print(f"🚀 Initializing {algo_select.label} in {mode_select.value} mode...")

        # Pass variables to your training function
        controller = run_cross_validation_or_training(
            algorithm=algo,
            mode=mode_select.value,
            action_mode=action_select.value,
            stop_logic=logic_select.value
        )

        print(f"✅ Training Complete!")
        globals()['latest_controller'] = controller

# 4. Connect and Display
run_button.on_click(on_button_clicked)
display(algo_select, mode_select, action_select, logic_select, tune_toggle, run_button, out)
# Out:
# Dropdown(description='Algorithm:', options=(('Q-Learning', 'qlearning'), ('DQN', 'dqn'), ('SARSA', 'sarsa')), …
# Dropdown(description='State Mode:', options=(('2D (Pole Only)', '2D'), ('4D (Full State)', '4D')), value='2D')
# Dropdown(description='Action Type:', options=(('Discrete (0 or 1)', 'discrete'),), value='discrete')
# Dropdown(description='Stop Logic:', options=(('Fixed Episodes', 'fixed'), ('Until Overfitting', 'overfitting')…
# Checkbox(value=False, description='Tune Hyperparameters?', indent=False)
# Button(button_style='success', description='Launch Training', icon='play', style=ButtonStyle())
# Output()

# %%
print(f"  Learning Rate: {config.CONTROL_PARAMS['learning_rate']}")
print(f"  Discount Factor: {config.CONTROL_PARAMS['discount_factor']}")
print(f"  Epsilon: {config.CONTROL_PARAMS['epsilon']}")

from cross_validation import run_cross_validation_or_training
import joblib

controller = run_cross_validation_or_training(model, '2D' , 'fixed')
# Out:
#   Learning Rate: 0.001
#   Discount Factor: 0.99
#   Epsilon: 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3302172927.py in <cell line: 0>()
#       6 import joblib
#       7
# ----> 8 controller = run_cross_validation_or_training(model, '2D' , 'fixed')
#
# NameError: name 'model' is not defined

# %%
if controller is None:
  print("Yes)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4109781285.py in <cell line: 0>()
# ----> 1 if controller is None:
#       2   print("Yes)")
#
# NameError: name 'controller' is not defined

# %%
import os
import joblib
model_path = os.path.join(config.LOG_PARAMS['save_path'], 'trained_dqn_model_with_params.pkl')
if controller is not None:
    joblib.dump(controller, model_path)

# %% [markdown]
# # Testing for QLearning
#
# This section if for testing the model and saving the test logs, created by qlearning only

# %%
# Testing phase
import joblib
import os

model_path = os.path.join(config.LOG_PARAMS['save_path'], '/content/constrained-cartpole-rl/Results/best_model.pkl')
controller = joblib.load(model_path)

success_threshold=195

test_episodes = 100
test_rewards = []
test_lengths = []

test_logger = DataLogger(config.LOG_PARAMS)

# Initialize the environment
env = GymWrapper(gym.make('CartPole-v1'))

for episode in range(test_episodes):
    state, _ = env.reset()
    episode_reward = 0
    episode_length = 0

    while True:

        #env.render()
        # Get the action from the trained model without exploration (epsilon=0)
        action = controller.get_action(state, epsilon=0.0)
        #next_state, reward, done, _ = env.step(action)
          # Logging each step in the episode
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        test_logger.log(state, action, reward, next_state)

        state = next_state
        episode_reward += reward
        episode_length += 1
        if done:
            break

    # Log the episode-level data
    test_logger.log_episode(episode, episode_reward, episode_length)

    test_rewards.append(episode_reward)
    test_lengths.append(episode_length)

# Calculate and print the test metrics
average_test_reward = np.mean(test_rewards)
average_test_length = np.mean(test_lengths)
success_rate = np.mean([1 if r >= success_threshold else 0 for r in test_rewards])

print(f"Average Test Reward over {test_episodes} episodes: {average_test_reward}")
print(f"Average Test Episode Length: {average_test_length}")
print(f"Success Rate: {success_rate * 100}%")
# Out:
# Average Test Reward over 100 episodes: 22.43
# Average Test Episode Length: 22.43
# Success Rate: 0.0%

# %%
test_logger.save_metrics(state='test')

# Optionally, save logs and plot the results
test_logger.save_logs_as_csv(state='test')
test_logger.plot_results(model_name='QLearning_Test', window_size=10)

# %% [markdown]
# # Testing for DQN
# This section is to be used only for testing the DQN model and to display and save its results

# %%
'''import gymnasium as gym
from gymnasium.wrappers import RecordVideo
import joblib
import torch
import os
import time
import glob
import base64
from IPython.display import HTML
from IPython import display as ipythondisplay
from gym_wrapper import GymWrapper
import shutil
import config
from pyvirtualdisplay import Display

# Install Colab dependencies automatically
os.system("apt-get install -y xvfb ffmpeg > /dev/null 2>&1")
os.system("pip install pyvirtualdisplay > /dev/null 2>&1")

def test_all(config, num_episodes=5):
    # 1. Start virtual display
    display = Display(visible=0, size=(1400, 900))
    display.start()

    # 2. Find the LATEST session folder in Results
    results_base = config.LOG_PARAMS['save_path']
    all_sessions = [os.path.join(results_base, d) for d in os.listdir(results_base)
                    if os.path.isdir(os.path.join(results_base, d))]

    if not all_sessions:
        print("No sessions found.")
        display.stop()
        return

    latest_session = max(all_sessions, key=os.path.getmtime)
    print(f" Testing latest session: {latest_session}")

    # 3. Find the best model file inside that folder
    model_files = glob.glob(os.path.join(latest_session, "*.pkl"))
    if not model_files:
        print("No .pkl model found.")
        display.stop()
        return

    # Priority: load the one with 'best' in the name, otherwise the first one
    best_match = [f for f in model_files if 'best' in f.lower()]
    model_path = best_match[0] if best_match else model_files[0]
    print(f" Loading model: {os.path.basename(model_path)}")

    # 4. Load and Identify Model Type
    loaded_data = joblib.load(model_path)

    # Handle both dictionary format and legacy direct-object format
    if isinstance(loaded_data, dict) and 'model' in loaded_data:
        controller = loaded_data['model']
        saved_mode = loaded_data.get('state_mode', config.STATE_MODE)
        saved_action = loaded_data.get('action_mode', 'discrete')
    else:
        controller = loaded_data
        saved_mode = config.STATE_MODE
        saved_action = 'discrete'

    # Set to eval mode if it's a DQN
    if hasattr(controller, 'q_network'):
        controller.q_network.eval()
        print("Setting DQN to eval mode.")

    # 5. Setup Environment and Video
    video_folder = os.path.join(latest_session, 'videos')
    if os.path.exists(video_folder):
        shutil.rmtree(video_folder)

    raw_env = gym.make('CartPole-v1', render_mode='rgb_array', max_episode_steps=2000)
    recorded_env = RecordVideo(raw_env, video_folder=video_folder, episode_trigger=lambda x: True)
    env = GymWrapper(recorded_env, mode=saved_mode, action_mode=saved_action)

    # 6. Run Test Loop
    for episode in range(num_episodes):
        state, _ = env.reset()
        done = False
        total_reward = 0

        while not done:
            #action = controller.get_action(state, explore=False)
            if hasattr(controller, 'q_table'):
              action = controller.get_action(state)
            else:
              action = controller.get_action(state, explore=False)

            state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += reward

        print(f"Episode {episode + 1}: Reward = {total_reward}")

    env.close()
    time.sleep(1)
    display.stop()
    return video_folder # Return for the show_video function

def show_session_video(video_folder):
    mp4list = glob.glob(os.path.join(video_folder, '*.mp4'))
    if len(mp4list) > 0:
        mp4 = sorted(mp4list)[-1] # Show the latest video
        video = open(mp4, 'rb').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data=<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>.format(encoded.decode('ascii'))))
    else:
        print("No video found.")

# --- EXECUTION ---
video_dir = test_all(config)
if video_dir:
    show_session_video(video_dir)'''

import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium.wrappers import RecordVideo
import joblib
import torch
import os
import time
import glob
import base64
from IPython.display import HTML
from IPython import display as ipythondisplay
from gym_wrapper import GymWrapper
import shutil
import config
from pyvirtualdisplay import Display

def test_all(config, num_episodes=10):
    display = Display(visible=0, size=(1400, 900))
    display.start()

    # 1. Directory Setup
    results_base = config.LOG_PARAMS['save_path']
    all_sessions = [os.path.join(results_base, d) for d in os.listdir(results_base)
                    if os.path.isdir(os.path.join(results_base, d))]

    if not all_sessions:
        print("No sessions found.")
        display.stop()
        return None, None

    latest_session = max(all_sessions, key=os.path.getmtime)
    print(f"📂 Testing session: {latest_session}")

    # 2. Model Loading
    model_files = glob.glob(os.path.join(latest_session, "*.pkl"))
    # Priority: session_best_peak, then best_model, then any pkl
    best_match = [f for f in model_files if 'session_best_peak' in f.lower()]
    if not best_match:
        best_match = [f for f in model_files if 'best' in f.lower()]

    model_path = best_match[0] if best_match else model_files[0]
    print(f"🤖 Loading Model: {os.path.basename(model_path)}")

    loaded_data = joblib.load(model_path)
    #controller = loaded_data['model'] if isinstance(loaded_data, dict) else loaded_data

    if isinstance(loaded_data, dict) and 'model' in loaded_data:
        controller = loaded_data['model']
        # Use saved settings if they exist, otherwise fall back to config
        saved_mode = loaded_data.get('state_mode', config.STATE_MODE)
        # Use 'discrete' as a safe default for Action Mode
        saved_action = loaded_data.get('action_mode', 'discrete')
    else:
        controller = loaded_data
        saved_mode = config.STATE_MODE
        saved_action = 'discrete'


    if hasattr(controller, 'q_network'):
        controller.q_network.eval()
        print("🔍 Mode: DQN (Eval)")
    elif hasattr(controller, 'q_table'):
        print("🔍 Mode: Q-Learning/SARSA (Tabular)")

    # 3. Environment Setup
    video_folder = os.path.join(latest_session, 'testing_videos')
    if os.path.exists(video_folder):
        shutil.rmtree(video_folder)

    # Note: RecordVideo adds 'rl-video-episode-0' to filenames
    raw_env = gym.make('CartPole-v1', render_mode='rgb_array', max_episode_steps=config.MAX_STEPS)
    recorded_env = RecordVideo(raw_env, video_folder=video_folder, episode_trigger=lambda x: True)
    env = GymWrapper(recorded_env, mode=saved_mode, action_mode=saved_action)

    # 4. Test Loop & Logging
    test_stats = []
    best_reward = -1
    best_vid_idx = 0

    for episode in range(num_episodes):
        state, _ = env.reset()
        done = False
        total_reward = 0

        while not done:
            # Logic to handle both Q-Table and DQN controllers
            if hasattr(controller, 'q_table'):
                action = controller.get_action(state)
            else:
                with torch.no_grad():
                    action = controller.get_action(state, explore=False)

            state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += reward

        print(f"🎬 Episode {episode + 1}: Reward = {total_reward}")

        # Track the best video to show later
        if total_reward >= best_reward:
            best_reward = total_reward
            best_vid_idx = episode

        test_stats.append({
            'episode': episode + 1,
            'reward': total_reward,
        })

    # 5. Save Testing Logs
    df = pd.DataFrame(test_stats)
    log_path = os.path.join(latest_session, "testing_performance_logs.csv")
    df.to_csv(log_path, index=False)
    print(f"📊 Testing logs saved to: {log_path}")
    print(f"📈 Average Test Reward: {df['reward'].mean():.2f}")

    env.close()
    display.stop()
    return video_folder, best_vid_idx, best_reward

def show_best_video(video_folder, best_idx, best_score):
    # RecordVideo names files like 'rl-video-episode-0.mp4'
    # We find the one that matches our best_idx
    mp4list = glob.glob(os.path.join(video_folder, f'rl-video-episode-{best_idx}.mp4'))

    if not mp4list:
        # Fallback if naming convention differs
        mp4list = sorted(glob.glob(os.path.join(video_folder, '*.mp4')))

    if len(mp4list) > 0:
        mp4 = mp4list[0]
        print(f"\n🌟 DISPLAYING BEST RUN: Episode {best_idx + 1} (Score: {best_score})")

        video = open(mp4, 'rb').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video autoplay loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("No videos found to display.")

# --- EXECUTION ---
video_dir, best_ep, best_val = test_all(config, num_episodes=5)
if video_dir:
    show_best_video(video_dir, best_ep, best_val)
# Out:
# 📂 Testing session: ./Results/qlearning_4D_20260318-192258
# 🤖 Loading Model: qlearning_best_model.pkl
# 🔍 Mode: Q-Learning/SARSA (Tabular)
# 🎬 Episode 1: Reward = 116.0
# 🎬 Episode 2: Reward = 58.0
# 🎬 Episode 3: Reward = 158.0
# 🎬 Episode 4: Reward = 61.0
# 🎬 Episode 5: Reward = 116.0
# 📊 Testing logs saved to: ./Results/qlearning_4D_20260318-192258/testing_performance_logs.csv
# 📈 Average Test Reward: 101.80
#
# 🌟 DISPLAYING BEST RUN: Episode 3 (Score: 158.0)
# <video autoplay loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
import numpy as np
import gymnasium as gym
import joblib
import os
import matplotlib.pyplot as plt
from gym_wrapper import GymWrapper
import config

def run_stress_test(config, test_type='mass'):
    # Load your trained model
    model_path = os.path.join(config.LOG_PARAMS['save_path'], 'trained_dqn_model_with_params.pkl')
    model_info = joblib.load(model_path)
    controller = model_info['model']

    if hasattr(controller.model, 'eval'):
        controller.model.eval()

    results = []

    # Define the range for the stress test
    # We will test pole mass from 0.1 (standard) up to 2.0 (very heavy)
    test_range = np.linspace(0.1, 2.0, 10) if test_type == 'mass' else np.linspace(10.0, 2.0, 10)

    print(f"Starting Stress Test on: {test_type}")

    for val in test_range:
        # Create environment with MODIFIED physics
        if test_type == 'mass':
            # Create standard env then manually override the mass
            raw_env = gym.make('CartPole-v1')
            raw_env.unwrapped.masspole = val
            raw_env.unwrapped.total_mass = raw_env.unwrapped.masscart + val
            raw_env.unwrapped.polemass_length = val * raw_env.unwrapped.length
        else:
            # Testing Reduced Force (Motor Failure simulation)
            raw_env = gym.make('CartPole-v1')
            raw_env.unwrapped.force_mag = val

        env = GymWrapper(raw_env, mode='4D', action_mode='discrete')

        episode_rewards = []
        for _ in range(10): # Run 10 trials per setting for an average
            state, _ = env.reset()
            done = False
            total_r = 0
            while not done:
                action = controller.get_action(state, explore=False)
                state, reward, terminated, truncated, _ = env.step(action)
                done = terminated or truncated
                total_r += reward
            episode_rewards.append(total_r)

        avg_reward = np.mean(episode_rewards)
        results.append(avg_reward)
        print(f"{test_type} value: {val:.2f} | Avg Reward: {avg_reward}")
        env.close()

    return test_range, results

# Execute the test
mass_range, mass_scores = run_stress_test(config, test_type='mass')

# Plotting the "Breaking Point"
plt.figure(figsize=(10, 5))
plt.plot(mass_range, mass_scores, marker='o', color='red')
plt.title('DQN Robustness: Impact of Increasing Pole Mass')
plt.xlabel('Pole Mass (kg) [Standard = 0.1]')
plt.ylabel('Average Reward (Max 500)')
plt.grid(True)
plt.show()
# Out:
# Starting Stress Test on: mass
# mass value: 0.10 | Avg Reward: 500.0
# mass value: 0.31 | Avg Reward: 500.0
# mass value: 0.52 | Avg Reward: 500.0
# mass value: 0.73 | Avg Reward: 500.0
# mass value: 0.94 | Avg Reward: 500.0
# mass value: 1.16 | Avg Reward: 500.0
# mass value: 1.37 | Avg Reward: 500.0
# mass value: 1.58 | Avg Reward: 500.0
# mass value: 1.79 | Avg Reward: 500.0
# mass value: 2.00 | Avg Reward: 500.0

# %%
'''import os
import glob

# Check if the video folder has files
#video_files = glob.glob('/content/constrained-cartpole-rl/video/rl-video-episode-4.mp4')
video_files = glob.glob('/content/constrained-cartpole-rl/Results/qlearning_4D_20260318-184722/videos/rl-video-episode-1.mp4')
video_folder = os.path.join(latest_session, 'videos')
print(f"Found {len(video_files)} videos: {video_files}")

if len(video_files) > 0:
    show_session_video(video_folder) # Run the helper function we wrote earlier
else:
    print("Video was not saved properly due to the crash.")'''

from google.colab.patches import cv2_imshow
import cv2

def show_first_frame(video_path):
    cap = cv2.VideoCapture(video_path)
    ret, frame = cap.read()
    if ret:
        cv2_imshow(frame) # This replaces cv2.imshow()
    cap.release()

show_first_frame("/content/constrained-cartpole-rl/Results/qlearning_4D_20260318-184722/videos/rl-video-episode-1.mp4")
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
import numpy as np
import gymnasium as gym
import joblib
import os
import matplotlib.pyplot as plt
from gym_wrapper import GymWrapper
from pyvirtualdisplay import Display
from gymnasium.wrappers import RecordVideo
import config

def stress_test_initial_angle(config, num_trials=5):
    # Load Model
    model_path = os.path.join(config.LOG_PARAMS['save_path'], 'trained_dqn_model_with_params.pkl')
    model_info = joblib.load(model_path)
    controller = model_info['model']
    if hasattr(controller.model, 'eval'): controller.model.eval()

    # Define angles from 0.05 (normal) to 0.4 radians (approx 23 degrees - very steep!)
    # Note: CartPole-v1 failure threshold is 0.209 radians (12 degrees),
    # but we want to see if it can recover even when starting PAST the fail point.
    angle_thresholds = np.linspace(0.01, 0.20, 10)
    avg_rewards = []

    print("Starting Initial Angle Stress Test...")

    for angle in angle_thresholds:
        raw_env = gym.make('CartPole-v1')
        env = GymWrapper(raw_env, mode='4D', action_mode='discrete')

        trial_rewards = []
        for _ in range(num_trials):
            # Manually reset with a specific extreme angle
            state, _ = env.reset()
            # Overwrite the pole angle (index 2 in 4D state) with the test angle
            # We alternate left and right tilt
            side = 1 if np.random.random() > 0.5 else -1
            env.env.unwrapped.state[2] = angle * side

            done = False
            total_r = 0
            while not done:
                action = controller.get_action(env._filter_state(env.env.unwrapped.state), explore=False)
                state, reward, terminated, truncated, _ = env.step(action)
                done = terminated or truncated
                total_r += reward
            trial_rewards.append(total_r)

        avg_rewards.append(np.mean(trial_rewards))
        print(f"Start Angle: {np.degrees(angle):.2f}° | Avg Reward: {np.mean(trial_rewards)}")
        env.close()

    return angle_thresholds, avg_rewards

# Execute and Plot
angles, scores = stress_test_initial_angle(config)

plt.figure(figsize=(10, 5))
plt.plot(np.degrees(angles), scores, marker='s', linestyle='--', color='blue')
plt.title('DQN Robustness: Survival by Starting Pole Angle')
plt.xlabel('Initial Pole Angle (Degrees)')
plt.ylabel('Average Reward')
plt.axvline(x=12, color='red', linestyle=':', label='Default Failure Limit (12°)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Starting Initial Angle Stress Test...
# Start Angle: 0.57° | Avg Reward: 500.0
# Start Angle: 1.78° | Avg Reward: 500.0
# Start Angle: 2.99° | Avg Reward: 500.0
# Start Angle: 4.20° | Avg Reward: 500.0
# Start Angle: 5.41° | Avg Reward: 500.0
# Start Angle: 6.62° | Avg Reward: 500.0
# Start Angle: 7.83° | Avg Reward: 500.0
# Start Angle: 9.04° | Avg Reward: 500.0
# Start Angle: 10.25° | Avg Reward: 500.0
# Start Angle: 11.46° | Avg Reward: 500.0

# %%
def record_recovery_video(config):
    display = Display(visible=0, size=(1400, 900))
    display.start()

    raw_env = gym.make('CartPole-v1', render_mode='rgb_array')
    # Use a folder named 'recovery_video'
    recorded_env = RecordVideo(raw_env, video_folder='./recovery_video', episode_trigger=lambda x: True)
    env = GymWrapper(recorded_env, mode='4D', action_mode='discrete')

    model_path = os.path.join(config.LOG_PARAMS['save_path'], 'trained_dqn_model_with_params.pkl')
    controller = joblib.load(model_path)['model']

    state, _ = env.reset()
    # Force an extreme start: 0.18 radians (approx 10.3 degrees)
    env.env.env.unwrapped.state[2] = 0.25

    done = False
    while not done:
        action = controller.get_action(state, explore=False)
        state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

    env.close()
    display.stop()
    print("Recovery video recorded in ./recovery_video")

record_recovery_video(config)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content/constrained-cartpole-rl/recovery_video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Recovery video recorded in ./recovery_video

# %%
env.close()

# %% [markdown]
# # Testing Sarsa
#
# This section is to be used only for testing the Sarsa model and to display and save its results

# %%
import matplotlib.pyplot as plt
import numpy as np
import joblib
import os

def plot_test_results(logger, save_path=None):
    plt.figure(figsize=(12, 6))

    # Plot test rewards
    plt.plot(logger.episode_rewards, label='Test Reward', color='green')

    # Optionally, plot average reward (moving average)
    window_size = 10
    avg_rewards = np.convolve(logger.episode_rewards, np.ones(window_size) / window_size, mode='valid')
    plt.plot(range(len(avg_rewards)), avg_rewards, label='Average Test Reward', color='orange')

    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('SARSA Test Rewards')
    plt.legend()

    if save_path:
        plt.savefig(save_path)
    plt.show()

# Modify the test_sarsa function to include plotting
def test_sarsa(model_class, config, num_episodes=100):
    env = GymWrapper(gym.make('CartPole-v1'))

    # Load the trained SARSA model
    model_path = os.path.join(config.LOG_PARAMS['save_path'], 'sarsa_model.pkl')
    controller = joblib.load(model_path)

    test_rewards = []
    test_lengths = []

    for episode in range(num_episodes):
        state = env.reset()
        episode_reward = 0
        done = False
        t = 0

        action = controller.get_action(state)  # Initial action

        while not done:
            next_state, reward, done, _ = env.step(action)
            next_action = controller.get_action(next_state)  # Next action

            # No update to Q-table here, just testing
            state = next_state
            action = next_action
            episode_reward += reward
            t += 1

        test_rewards.append(episode_reward)
        test_lengths.append(t)

        print(f"Episode {episode + 1}/{num_episodes}: Reward = {episode_reward}, Length = {t}")

    # Calculate and print the average reward and length
    average_test_reward = sum(test_rewards) / num_episodes
    average_test_length = sum(test_lengths) / num_episodes

    print(f"Average Test Reward over {num_episodes} episodes: {average_test_reward}")
    print(f"Average Test Episode Length: {average_test_length}")

    # Save the test results in logs
    test_logger = DataLogger(config.LOG_PARAMS)
    test_logger.episode_rewards = test_rewards
    test_logger.episode_lengths = test_lengths
    test_logger.save_logs_as_csv(state='test')
    test_logger.save_metrics(state='test')

    # Plot and save the test results
    plot_path = os.path.join(config.LOG_PARAMS['save_path'], 'sarsa_test_plot.png')
    plot_test_results(test_logger, save_path=plot_path)

    env.close()

# %%
test_sarsa(SarsaControl, config)
# Out:
# Episode 1/100: Reward = 10.0, Length = 10
# Episode 2/100: Reward = 13.0, Length = 13
# Episode 3/100: Reward = 10.0, Length = 10
# Episode 4/100: Reward = 9.0, Length = 9
# Episode 5/100: Reward = 11.0, Length = 11
# Episode 6/100: Reward = 13.0, Length = 13
# Episode 7/100: Reward = 9.0, Length = 9
# Episode 8/100: Reward = 9.0, Length = 9
# Episode 9/100: Reward = 10.0, Length = 10
# Episode 10/100: Reward = 9.0, Length = 9
# Episode 11/100: Reward = 9.0, Length = 9
# Episode 12/100: Reward = 10.0, Length = 10
# Episode 13/100: Reward = 9.0, Length = 9
# Episode 14/100: Reward = 13.0, Length = 13
# Episode 15/100: Reward = 13.0, Length = 13
# Episode 16/100: Reward = 10.0, Length = 10
# Episode 17/100: Reward = 13.0, Length = 13
# Episode 18/100: Reward = 9.0, Length = 9
# Episode 19/100: Reward = 9.0, Length = 9
# Episode 20/100: Reward = 12.0, Length = 12
# Episode 21/100: Reward = 9.0, Length = 9
# Episode 22/100: Reward = 11.0, Length = 11
# ...
